# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\Users\moomad\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
matches_for_predict = pd.read_csv('matches_for_predict.csv')
futureM = pd.read_csv('Futures.csv')
model = load_model("FinalData.h5")
# Out:
# WARNING:tensorflow:From c:\Users\moomad\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
predictions = model.predict(matches_for_predict)
for index, predict in enumerate(predictions):
    print(f'{futureM.loc[index, "Team"]} VS {futureM.loc[index, "Opponent"]}')
    print(predict)
    if np.argmax(predict) == 1:
        print("***** Draw *****")
    elif np.argmax(predict) == 0:
        if futureM.loc[index, "Venue"] == 'Home':
            print(
                f"Home team wins. ***** {futureM.loc[index, 'Team']} *****")
        elif futureM.loc[index, "Venue"] == 'Away':
            print(
                f"Away team wins. ***** {futureM.loc[index, 'Team']} *****")
    else:
        if futureM.loc[index, "Venue"] == 'Home':
            print(
                f"Away team wins. ***** {futureM.loc[index, 'Opponent']} *****")
        elif futureM.loc[index, "Venue"] == 'Away':
            print(
                f"Away team wins. ***** {futureM.loc[index, 'Team']} *****")
    # print(predict)
    print('---------------------------------------------------------')
    print('---------------------------------------------------------')
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Liverpool VS Manchester City
# [0.8643943  0.11665422 0.01895143]
# Home team wins. ***** Liverpool *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Arsenal VS Brentford
# [0.94368094 0.04986361 0.00645546]
# Home team wins. ***** Arsenal *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Aston Villa VS Tottenham
# [0.9686465  0.02860451 0.00274895]
# Home team wins. ***** Aston Villa *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Manchester Utd VS Everton
# [0.8669074  0.10252599 0.03056666]
# Home team wins. ***** Manchester Utd *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# West Ham VS Burnley
# [0.94443333 0.04772392 0.00784267]
# Home team wins. ***** West Ham *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Newcastle Utd VS Chelsea
# [0.06152283 0.04661672 0.8918604 ]
# Away team wins. ***** Newcastle Utd *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Brighton VS Nott'ham Forest
# [0.85025746 0.11643622 0.03330629]
# Home team wins. ***** Brighton *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Wolves VS Fulham
# [0.9153796  0.06069958 0.02392078]
# Home team wins. ***** Wolves *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Bournemouth VS Sheffield Utd
# [0.9781818  0.01868011 0.00313821]
# Home team wins. ***** Bournemouth *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Crystal Palace VS Luton Town
# [0.9544574  0.03820181 0.00734074]
# Home team wins. ***** Crystal Palace *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Real Madrid VS Celta Vigo
# [0.9741165  0.0225332  0.00335034]
# Home team wins. ***** Real Madrid *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Girona VS Osasuna
# [0.4842143  0.4324634  0.08332223]
# Home team wins. ***** Girona *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Barcelona VS Mallorca
# [0.64758843 0.29860514 0.05380642]
# Home team wins. ***** Barcelona *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Atlético Madrid VS Cádiz
# [0.4450367  0.17065004 0.3843133 ]
# Away team wins. ***** Atlético Madrid *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Athletic Club VS Las Palmas
# [0.4175764  0.33038655 0.25203708]
# Away team wins. ***** Athletic Club *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Betis VS Villarreal
# [0.8945029  0.07511219 0.03038491]
# Home team wins. ***** Betis *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Real Sociedad VS Granada
# [0.04413616 0.02542505 0.93043876]
# Away team wins. ***** Real Sociedad *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Valencia VS Getafe
# [0.95533454 0.02914266 0.01552278]
# Home team wins. ***** Valencia *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Alavés VS Rayo Vallecano
# [0.9648645  0.02510327 0.01003228]
# Home team wins. ***** Alavés *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Sevilla VS Almería
# [0.8402686  0.10181306 0.05791832]
# Away team wins. ***** Sevilla *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Leverkusen VS Wolfsburg
# [0.9219059  0.06587795 0.01221613]
# Home team wins. ***** Leverkusen *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Bayern Munich VS Mainz 05
# [0.91822845 0.07211032 0.00966128]
# Home team wins. ***** Bayern Munich *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Stuttgart VS Union Berlin
# [0.40835902 0.5205834  0.07105764]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Dortmund VS Werder Bremen
# [0.8922558  0.02786157 0.07988263]
# Away team wins. ***** Dortmund *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# RB Leipzig VS Darmstadt 98
# [0.9824452  0.01619691 0.00135797]
# Home team wins. ***** RB Leipzig *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Eint Frankfurt VS Hoffenheim
# [0.7075667  0.25885856 0.03357473]
# Home team wins. ***** Eint Frankfurt *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Freiburg VS Bochum
# [0.1897704  0.07571775 0.7345119 ]
# Away team wins. ***** Freiburg *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Augsburg VS Heidenheim
# [0.17302902 0.6861921  0.14077887]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# M'Gladbach VS Köln
# [0.9250081  0.06202723 0.0129647 ]
# Home team wins. ***** M'Gladbach *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Inter VS Bologna
# [0.06361481 0.18100625 0.75537896]
# Away team wins. ***** Inter *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Juventus VS Atalanta
# [0.9482118  0.04463987 0.00714836]
# Home team wins. ***** Juventus *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Milan VS Empoli
# [0.94053286 0.0514502  0.00801696]
# Home team wins. ***** Milan *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Roma VS Fiorentina
# [0.00859485 0.03519733 0.95620775]
# Away team wins. ***** Roma *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Napoli VS Torino
# [0.92771083 0.05791409 0.01437505]
# Home team wins. ***** Napoli *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lazio VS Udinese
# [0.4073295  0.53285855 0.05981194]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Monza VS Genoa
# [0.00266435 0.01767747 0.97965825]
# Away team wins. ***** Monza *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lecce VS Hellas Verona
# [0.95915437 0.03076765 0.0100779 ]
# Home team wins. ***** Lecce *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Frosinone VS Sassuolo
# [0.11064737 0.3324825  0.5568702 ]
# Away team wins. ***** Frosinone *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Cagliari VS Salernitana
# [0.89115363 0.08272109 0.02612531]
# Home team wins. ***** Cagliari *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Paris S-G VS Reims
# [0.23514137 0.7039179  0.06094072]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Brest VS Lens
# [0.12387676 0.16024177 0.71588147]
# Away team wins. ***** Brest *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Monaco VS Strasbourg
# [0.18513702 0.5351113  0.2797517 ]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lille VS Rennes
# [0.9573997  0.03429984 0.00830039]
# Home team wins. ***** Lille *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Nice VS Montpellier
# [0.8153662  0.16649951 0.01813423]
# Home team wins. ***** Nice *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Marseille VS Nantes
# [0.7869061  0.18888745 0.02420636]
# Home team wins. ***** Marseille *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Toulouse VS Le Havre
# [0.55351645 0.13375393 0.31272954]
# Away team wins. ***** Toulouse *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lyon VS Lorient
# [0.00429574 0.0283209  0.9673834 ]
# Away team wins. ***** Lyon *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Clermont Foot VS Metz
# [0.01078014 0.03391911 0.9553007 ]
# Away team wins. ***** Clermont Foot *****
# ---------------------------------------------------------
# ---------------------------------------------------------

# %%
predictions = model.predict(matches_for_predict)
for index, predict in enumerate(predictions):
    print(f'{futureM.loc[index, "Team"]} VS {futureM.loc[index, "Opponent"]}')
    if np.argmax(predict) == 1:
        print("***** Draw *****")
    elif np.argmax(predict) == 0:
        if futureM['Venue'].iloc[index] == 'Home':
            print(
                f"Home team wins. ***** {futureM['Team'].iloc[index]} *****")
        elif futureM['Venue'].iloc[index] == 'Away':
            print(
                f"Away team wins. ***** {futureM['Team'].iloc[index]} *****")
    else:
        if futureM['Venue'].iloc[index] == 'Home':
            print(
                f"Away team wins. ***** {futureM['Opponent'].iloc[index]} *****")
        elif futureM['Venue'].iloc[index] == 'Away':
            print(
                f"Away team wins. ***** {futureM['Team'].iloc[index]} *****")
    # print(predict)
    print('---------------------------------------------------------')
    print('---------------------------------------------------------')
# Out:
# 2/2 [==============================] - 0s 0s/step
# Liverpool VS Manchester City
# Home team wins. ***** Liverpool *****
# ---------------------------------------------------------
# ---------------------------------------------------------
#