# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model

# %%
matches_for_predict = pd.read_csv('matches_for_predict.csv')
futureM = pd.read_csv('Futures.csv')
model = load_model("FinalData.h5")

# %%
predictions = model.predict(matches_for_predict)
for index, predict in enumerate(predictions):
    print(f'{futureM.loc[index, "Team"]} VS {futureM.loc[index, "Opponent"]}')
    print(predict)
    if np.argmax(predict) == 1:
        print("***** Draw *****")
    elif np.argmax(predict) == 0:
        if futureM.loc[index, "Venue"] == 'Home':
            print(
                f"Home team wins. ***** {futureM.loc[index, 'Team']} *****")
        elif futureM.loc[index, "Venue"] == 'Away':
            print(
                f"Away team wins. ***** {futureM.loc[index, 'Team']} *****")
    else:
        if futureM.loc[index, "Venue"] == 'Home':
            print(
                f"Away team wins. ***** {futureM.loc[index, 'Opponent']} *****")
        elif futureM.loc[index, "Venue"] == 'Away':
            print(
                f"Away team wins. ***** {futureM.loc[index, 'Team']} *****")
    # print(predict)
    print('---------------------------------------------------------')
    print('---------------------------------------------------------')
# Out:
# 2/2 [==============================] - 0s 7ms/step
# 3 VS 258
# [0.9494486  0.02438287 0.02616853]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 5 VS 334
# [0.89965934 0.06479283 0.03554785]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 156 VS 20
# [0.9503293  0.02356083 0.0261098 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 1 VS 1
# [0.92763644 0.0346843  0.03767929]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 12 VS 11
# [0.9395821  0.02898508 0.03143281]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 9 VS 8
# [0.03863236 0.03582756 0.92554015]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 14 VS 333
# [0.9237039  0.04349835 0.03279774]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 109 VS 169
# [0.9503941  0.02352233 0.02608349]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 11 VS 255
# [0.7175718  0.23619585 0.04623235]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 10 VS 512
# [0.84087497 0.12418997 0.03493503]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 59 VS 120
# [0.9441022  0.02687617 0.02902157]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 66 VS 280
# [0.9499344  0.02383862 0.02622693]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 57 VS 282
# [0.94949865 0.0241983  0.02630295]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 58 VS 312
# [0.02790536 0.02592256 0.9461721 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 72 VS 113
# [0.34172904 0.21838869 0.4398822 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 62 VS 121
# [0.94532245 0.02658734 0.02809025]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 68 VS 281
# [0.02831101 0.02629746 0.9453915 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 60 VS 110
# [0.9371664  0.0301206  0.03271312]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 70 VS 224
# [0.9505773  0.02336726 0.02605548]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 63 VS 339
# [0.026307   0.02444508 0.9492479 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 80 VS 140
# [0.5832362  0.3583454  0.05841846]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 76 VS 138
# [0.9248385  0.04162648 0.03353501]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 82 VS 299
# [0.7329703  0.210772   0.05625775]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 79 VS 136
# [0.02394279 0.02225878 0.95379835]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 81 VS 525
# [0.09931294 0.8570889  0.04359808]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# 83 VS 137
# [0.77477485 0.18820539 0.03701982]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 90 VS 341
# [0.0237977  0.02212457 0.95407784]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 87 VS 528
# [0.81886476 0.14178793 0.0393473 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 84 VS 150
# [0.42677367 0.16544156 0.40778476]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 22 VS 64
# [0.0369139  0.03424193 0.92884415]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 19 VS 53
# [0.9072523  0.05717663 0.03557104]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 24 VS 209
# [0.9051246  0.04814128 0.04673413]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 21 VS 50
# [0.03913265 0.03628911 0.9245782 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 20 VS 51
# [0.1398194  0.8156418  0.04453873]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# 23 VS 56
# [0.9463949  0.02584385 0.02776123]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 189 VS 47
# [0.03254671 0.03021043 0.9372429 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 160 VS 66
# [0.8671751  0.09516727 0.03765756]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 131 VS 49
# [0.02108937 0.9520818  0.02682884]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# 34 VS 348
# [0.8921359  0.07206794 0.03579608]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 38 VS 218
# [0.9315451  0.03818399 0.03027094]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 162 VS 326
# [0.01916667 0.95819825 0.02263507]
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# 39 VS 96
# [0.02626931 0.02441024 0.9493205 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 54 VS 98
# [0.94961035 0.02416501 0.02622467]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 45 VS 85
# [0.86607593 0.09802633 0.03589773]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 41 VS 93
# [0.9346814  0.03128991 0.03402855]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 55 VS 517
# [0.03740903 0.03469884 0.92789215]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 40 VS 327
# [0.0287195  0.02667497 0.9446055 ]
# ---------------------------------------------------------
# ---------------------------------------------------------
# 192 VS 82
# [0.069499   0.05819736 0.8723036 ]
# ---------------------------------------------------------
# ---------------------------------------------------------

# %%
predictions = model.predict(matches_for_predict)
for index, predict in enumerate(predictions):
    print(f'{futureM.loc[index, "Team"]} VS {futureM.loc[index, "Opponent"]}')
    if np.argmax(predict) == 1:
        print("***** Draw *****")
    elif np.argmax(predict) == 0:
        if futureM['Venue'].iloc[index] == 'Home':
            print(
                f"Home team wins. ***** {futureM['Team'].iloc[index]} *****")
        elif futureM['Venue'].iloc[index] == 'Away':
            print(
                f"Away team wins. ***** {futureM['Team'].iloc[index]} *****")
    else:
        if futureM['Venue'].iloc[index] == 'Home':
            print(
                f"Away team wins. ***** {futureM['Opponent'].iloc[index]} *****")
        elif futureM['Venue'].iloc[index] == 'Away':
            print(
                f"Away team wins. ***** {futureM['Team'].iloc[index]} *****")
    # print(predict)
    print('---------------------------------------------------------')
    print('---------------------------------------------------------')
# Out:
# 2/2 [==============================] - 0s 0s/step
# Liverpool VS Manchester City
# Home team wins. ***** Liverpool *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Arsenal VS Brentford
# Home team wins. ***** Arsenal *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Aston Villa VS Tottenham
# Home team wins. ***** Aston Villa *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Manchester Utd VS Everton
# Home team wins. ***** Manchester Utd *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# West Ham VS Burnley
# Home team wins. ***** West Ham *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Newcastle Utd VS Chelsea
# Away team wins. ***** Newcastle Utd *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Brighton VS Nott'ham Forest
# Home team wins. ***** Brighton *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Wolves VS Fulham
# Home team wins. ***** Wolves *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Bournemouth VS Sheffield Utd
# Home team wins. ***** Bournemouth *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Crystal Palace VS Luton Town
# Home team wins. ***** Crystal Palace *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Real Madrid VS Celta Vigo
# Home team wins. ***** Real Madrid *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Girona VS Osasuna
# Home team wins. ***** Girona *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Barcelona VS Mallorca
# Home team wins. ***** Barcelona *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Atlético Madrid VS Cádiz
# Away team wins. ***** Atlético Madrid *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Athletic Club VS Las Palmas
# Away team wins. ***** Athletic Club *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Betis VS Villarreal
# Home team wins. ***** Betis *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Real Sociedad VS Granada
# Away team wins. ***** Real Sociedad *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Valencia VS Getafe
# Home team wins. ***** Valencia *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Alavés VS Rayo Vallecano
# Home team wins. ***** Alavés *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Sevilla VS Almería
# Away team wins. ***** Sevilla *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Leverkusen VS Wolfsburg
# Home team wins. ***** Leverkusen *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Bayern Munich VS Mainz 05
# Home team wins. ***** Bayern Munich *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Stuttgart VS Union Berlin
# Home team wins. ***** Stuttgart *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Dortmund VS Werder Bremen
# Away team wins. ***** Dortmund *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# RB Leipzig VS Darmstadt 98
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Eint Frankfurt VS Hoffenheim
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Freiburg VS Bochum
# Away team wins. ***** Freiburg *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Augsburg VS Heidenheim
# Home team wins. ***** Augsburg *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# M'Gladbach VS Köln
# Home team wins. ***** M'Gladbach *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Inter VS Bologna
# Away team wins. ***** Inter *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Juventus VS Atalanta
# Home team wins. ***** Juventus *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Milan VS Empoli
# Home team wins. ***** Milan *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Roma VS Fiorentina
# Away team wins. ***** Roma *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Napoli VS Torino
# Home team wins. ***** Napoli *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lazio VS Udinese
# Home team wins. ***** Lazio *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Monza VS Genoa
# Away team wins. ***** Monza *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lecce VS Hellas Verona
# ***** Draw *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Frosinone VS Sassuolo
# Away team wins. ***** Frosinone *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Cagliari VS Salernitana
# Home team wins. ***** Cagliari *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Paris S-G VS Reims
# Home team wins. ***** Paris S-G *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Brest VS Lens
# Away team wins. ***** Brest *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Monaco VS Strasbourg
# Away team wins. ***** Monaco *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lille VS Rennes
# Home team wins. ***** Lille *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Nice VS Montpellier
# Home team wins. ***** Nice *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Marseille VS Nantes
# Home team wins. ***** Marseille *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Toulouse VS Le Havre
# Away team wins. ***** Toulouse *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Lyon VS Lorient
# Away team wins. ***** Lyon *****
# ---------------------------------------------------------
# ---------------------------------------------------------
# Clermont Foot VS Metz
# Away team wins. ***** Clermont Foot *****
# ---------------------------------------------------------
# ---------------------------------------------------------
