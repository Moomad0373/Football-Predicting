# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\Users\moomad\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
matches_for_predict = pd.read_csv('matches_for_predict.csv')
futureM = pd.read_csv('Futures.csv')
model = load_model("FinalData.h5")
# Out:
# WARNING:tensorflow:From c:\Users\moomad\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
predictions = model.predict(matches_for_predict)
for index, predict in enumerate(predictions):
    print(f'{futureM.loc[index, "Team"]} VS {futureM.loc[index, "Opponent"]}')
    if np.argmax(predict) == 1:
        print(f"***** {futureM['Team'].iloc[index]} wins *****")
    elif np.argmax(predict) == 0:
        print("***** Draw *****")
    else:
        print(f"***** {futureM['Opponent'].iloc[index]} wins *****")
    print(predict)
    print('--------------------------------')
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Liverpool VS Manchester City
# ***** Manchester City wins *****
# [0.01142147 0.1606614  0.82791716]
# --------------------------------
# Arsenal VS Brentford
# ***** Draw *****
# [0.44014347 0.16717097 0.39268562]
# --------------------------------
# Aston Villa VS Tottenham
# ***** Draw *****
# [0.45293158 0.20973794 0.33733055]
# --------------------------------
# Manchester Utd VS Everton
# ***** Everton wins *****
# [0.00874617 0.04676555 0.9444883 ]
# --------------------------------
# West Ham VS Burnley
# ***** Burnley wins *****
# [0.01587334 0.37492463 0.6092021 ]
# --------------------------------
# Newcastle Utd VS Chelsea
# ***** Chelsea wins *****
# [0.02416093 0.06002698 0.9158121 ]
# --------------------------------
# Brighton VS Nott'ham Forest
# ***** Nott'ham Forest wins *****
# [0.07881515 0.07698687 0.844198  ]
# --------------------------------
# Wolves VS Fulham
# ***** Fulham wins *****
# [0.0384494  0.16944009 0.7921105 ]
# --------------------------------
# Bournemouth VS Sheffield Utd
# ***** Draw *****
# [0.56255233 0.09440592 0.34304172]
# --------------------------------
# Crystal Palace VS Luton Town
# ***** Luton Town wins *****
# [0.2867687  0.26725125 0.44598004]
# --------------------------------
# Real Madrid VS Celta Vigo
# ***** Celta Vigo wins *****
# [0.0385108  0.13675985 0.8247293 ]
# --------------------------------
# Girona VS Osasuna
# ***** Osasuna wins *****
# [0.024471   0.07484885 0.9006801 ]
# --------------------------------
# Barcelona VS Mallorca
# ***** Mallorca wins *****
# [0.01770238 0.05933116 0.9229665 ]
# --------------------------------
# Atlético Madrid VS Cádiz
# ***** Cádiz wins *****
# [0.00946982 0.02755816 0.962972  ]
# --------------------------------
# Athletic Club VS Las Palmas
# ***** Las Palmas wins *****
# [0.01637264 0.03497756 0.9486498 ]
# --------------------------------
# Betis VS Villarreal
# ***** Villarreal wins *****
# [0.02196732 0.06388786 0.9141448 ]
# --------------------------------
# Real Sociedad VS Granada
# ***** Draw *****
# [0.52966166 0.1172966  0.35304174]
# --------------------------------
# Valencia VS Getafe
# ***** Getafe wins *****
# [0.02938684 0.1051675  0.86544573]
# --------------------------------
# Alavés VS Rayo Vallecano
# ***** Rayo Vallecano wins *****
# [0.01458887 0.03979076 0.9456204 ]
# --------------------------------
# Sevilla VS Almería
# ***** Almería wins *****
# [0.0024158  0.00754634 0.9900379 ]
# --------------------------------
# Leverkusen VS Wolfsburg
# ***** Wolfsburg wins *****
# [0.0351058  0.07012479 0.8947694 ]
# --------------------------------
# Bayern Munich VS Mainz 05
# ***** Mainz 05 wins *****
# [0.3103825  0.20970285 0.4799146 ]
# --------------------------------
# Stuttgart VS Union Berlin
# ***** Union Berlin wins *****
# [0.03323362 0.05788147 0.9088848 ]
# --------------------------------
# Dortmund VS Werder Bremen
# ***** Werder Bremen wins *****
# [0.02256031 0.06970587 0.90773386]
# --------------------------------
# RB Leipzig VS Darmstadt 98
# ***** Darmstadt 98 wins *****
# [0.02134198 0.34769586 0.6309622 ]
# --------------------------------
# Eint Frankfurt VS Hoffenheim
# ***** Hoffenheim wins *****
# [0.03008836 0.28084207 0.6890696 ]
# --------------------------------
# Freiburg VS Bochum
# ***** Bochum wins *****
# [0.01898589 0.01770593 0.96330804]
# --------------------------------
# Augsburg VS Heidenheim
# ***** Heidenheim wins *****
# [0.02101594 0.07838546 0.9005985 ]
# --------------------------------
# M'Gladbach VS Köln
# ***** Köln wins *****
# [0.00721683 0.01991183 0.9728714 ]
# --------------------------------
# Inter VS Bologna
# ***** Bologna wins *****
# [0.03644364 0.03739273 0.92616355]
# --------------------------------
# Juventus VS Atalanta
# ***** Juventus wins *****
# [0.03201894 0.9450731  0.02290794]
# --------------------------------
# Milan VS Empoli
# ***** Empoli wins *****
# [0.00728889 0.19696361 0.7957475 ]
# --------------------------------
# Roma VS Fiorentina
# ***** Fiorentina wins *****
# [0.0266957  0.03765956 0.93564475]
# --------------------------------
# Napoli VS Torino
# ***** Napoli wins *****
# [0.05055108 0.879348   0.07010092]
# --------------------------------
# Lazio VS Udinese
# ***** Lazio wins *****
# [0.10481407 0.88571036 0.00947555]
# --------------------------------
# Monza VS Genoa
# ***** Genoa wins *****
# [0.01651018 0.1508504  0.83263946]
# --------------------------------
# Lecce VS Hellas Verona
# ***** Hellas Verona wins *****
# [0.0369083  0.14939103 0.8137007 ]
# --------------------------------
# Frosinone VS Sassuolo
# ***** Sassuolo wins *****
# [0.02378844 0.0704383  0.9057733 ]
# --------------------------------
# Cagliari VS Salernitana
# ***** Salernitana wins *****
# [0.0423298  0.20923273 0.7484374 ]
# --------------------------------
# Paris S-G VS Reims
# ***** Reims wins *****
# [0.00818303 0.03865519 0.9531619 ]
# --------------------------------
# Brest VS Lens
# ***** Lens wins *****
# [0.01460039 0.04838037 0.9370193 ]
# --------------------------------
# Monaco VS Strasbourg
# ***** Strasbourg wins *****
# [0.01287061 0.03164345 0.955486  ]
# --------------------------------
# Lille VS Rennes
# ***** Rennes wins *****
# [0.01887726 0.07767507 0.90344775]
# --------------------------------
# Nice VS Montpellier
# ***** Montpellier wins *****
# [0.02162163 0.03603709 0.94234127]
# --------------------------------
# Marseille VS Nantes
# ***** Nantes wins *****
# [0.02451421 0.07916563 0.8963202 ]
# --------------------------------
# Toulouse VS Le Havre
# ***** Le Havre wins *****
# [0.00311174 0.01349093 0.9833973 ]
# --------------------------------
# Lyon VS Lorient
# ***** Lorient wins *****
# [0.01053775 0.04472992 0.9447323 ]
# --------------------------------
# Clermont Foot VS Metz
# ***** Metz wins *****
# [0.02285057 0.0550174  0.922132  ]
# --------------------------------
